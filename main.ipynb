# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
my_df = pd.read_csv("DollarTurkishLira.csv")
my_df
# Out:
#          Tarih    BUY   SELL
# 0   29-08-2023  26.53  26.57
# 1   31-08-2023  26.58  26.62
# 2   01-09-2023  26.67  26.71
# 3   04-09-2023  26.68  26.73
# 4   05-09-2023  26.74  26.78
# ..         ...    ...    ...
# 63  27-11-2023  28.81  28.86
# 64  28-11-2023  28.86  28.91
# 65  29-11-2023  28.88  28.93
# 66  30-11-2023  28.86  28.91
# 67  01-12-2023  28.82  28.87
#
# [68 rows x 3 columns]

# %%
my_df.plot(kind="line",grid=True,figsize=(10,7))
# Out:
# <Axes: >

# %%
X = np.array(my_df.index).reshape(-1,1)
y = my_df["BUY"].values

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

plt.figure(figsize=(10, 7))
plt.scatter(X, y, color='blue', label='Real Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
